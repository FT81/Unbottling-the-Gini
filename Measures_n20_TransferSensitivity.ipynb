# %%
import numpy as np
from numpy import random
import pandas as pd
import math
import statistics as stats
import scipy.stats 
from scipy.stats import skew

# %%
dataframe2 = pd.DataFrame(columns=['TransferNr','Quantile','TransferSum',
                                    'Gini','Ginitf','Ginid','CV',
                                    'rGini','rGinitf','rGinid',
                                    'lGini','lGinitf','lGinid',
                                    'Gsk','Gsktf','Gkd',
                                    'IndexS','IndexStf','IndexSd',
                                    'IndexW','IndexWtf','IndexWd',
                                    'skewness_paerson1','Skew','Skew2',
                                    'dMetric','absdMetric','summ','dMetricDollar',
                                    'bMeasure',
                                    'skewdivergence','SkewMMconform','bMMconform',
                                    'mean','median','stdv',
                                    'percent1','percent2','percent3','percent4','percent5',
                                    'percent6','percent7','percent8','percent9','percent10',
                                    'percent11','percent12','percent13','percent14','percent15',
                                    'percent16','percent17','percent18','percent19','percent20',
                                    'percent1tf','percent2tf','percent3tf','percent4tf','percent5tf',
                                    'percent6tf','percent7tf','percent8tf','percent9tf','percent10tf',
                                    'percent11tf','percent12tf','percent13tf','percent14tf','percent15tf',
                                    'percent16tf','percent17tf','percent18tf','percent19tf','percent20tf',
                                    'value1','value2','value3','value4','value5',
                                    'value6','value7','value8','value9','value10',
                                    'value11','value12','value13','value14','value15',
                                    'value16','value17','value18','value19','value20',
                                    'value1tf','value2tf','value3tf','value4tf','value5tf',
                                    'value6tf','value7tf','value8tf','value9tf','value10tf',
                                    'value11tf','value12tf','value13tf','value14tf','value15tf',
                                    'value16tf','value17tf','value18tf','value19tf','value20tf',
                                                          
                                  ])

# %%
i=0
while i <=5000:
   
    #Generate distributions with 20 values
    value1=np.random.randint(1,50)
    value2=np.random.randint(1,50)
    value3=np.random.randint(1,100)
    value4=np.random.randint(1,100)
    value5=np.random.randint(1,150)
    value6=np.random.randint(1,150)
    value7=np.random.randint(1,200)
    value8=np.random.randint(1,200)
    value9=np.random.randint(1,250)
    value10=np.random.randint(1,250)
    
    value11=np.random.randint(50,300)
    value12=np.random.randint(50,300)
    value13=np.random.randint(50,350)
    value14=np.random.randint(50,350)
    value15=np.random.randint(50,400)
    value16=np.random.randint(50,400)
    value17=np.random.randint(50,500)
    value18=np.random.randint(50,600)
    value19=np.random.randint(50,800)
    value20=np.random.randint(60,1000)
   
    wlist =[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
            value11,value12,value13,value14,value15,value16,value17,value18,value19,value20]
    wlist.sort()
    
    a=wlist[0]
    b=wlist[1]
    c=wlist[2]
    d=wlist[3]
    e=wlist[4]
    f=wlist[5]
    g=wlist[6]
    h=wlist[7]
    j=wlist[8]
    k=wlist[9]
    l=wlist[10]
    m=wlist[11]
    n=wlist[12]
    o=wlist[13]
    p=wlist[14]
    q=wlist[15]
    r=wlist[16]
    s=wlist[17]
    t=wlist[18]
    u=wlist[19]
    
    distr =([value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
             value11,value12,value13,value14,value15,value16,value17,value18,value19,value20])
    
    summ=(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u)
    mean=(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u)/20
    median=np.median(wlist)
    vari=np.var(wlist)
    stdv=np.std(wlist)
    ####################################################################
    #Coefficient of Variation
    CV=stdv/mean
    
    ################################
    #lGini (=G_sk-) weights= Starting with weight n-1(=19) divided by n/2(=10) 
    #Decreasing with the rank in the cumulative distribution.
    
    lweight1=19/10
    lweight2=18/10
    lweight3=17/10
    lweight4=16/10
    lweight5=15/10
    lweight6=14/10
    lweight7=13/10
    lweight8=12/10
    lweight9=11/10
    lweight10=10/10
    lweight11=9/10
    lweight12=8/10
    lweight13=7/10
    lweight14=6/10
    lweight15=5/10
    lweight16=4/10
    lweight17=3/10
    lweight18=2/10
    lweight19=1/10
    
    ##############################
    #G_sk+ weights= Starting with weight 1 divided by n/2(=10) 
    #Increasing with the rank in the cumulative distribution to (n-1)/(n/2)
    
    rweight1=1/10
    rweight2=2/10
    rweight3=3/10
    rweight4=4/10
    rweight5=5/10
    rweight6=6/10
    rweight7=7/10
    rweight8=8/10
    rweight9=9/10
    rweight10=10/10 
    rweight11=11/10
    rweight12=12/10
    rweight13=13/10
    rweight14=14/10
    rweight15=15/10
    rweight16=16/10
    rweight17=17/10
    rweight18=18/10
    rweight19=19/10
   
    #####################################################################################################
    #################################################
    #(n*(n-1))/2 = 190 possible progressive transfers
    TransferNr=np.random.randint(1,190)
    TransferSum=random.choice([0.1,0.2,0.3,0.4,0.45,0.49])

    ###############################
    
    if(TransferNr==1):
        value1tf=a+TransferSum
        value2tf=b-TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='b2a'
        
        
    elif(TransferNr==2):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c-TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='c2a' 
        
        
    elif(TransferNr==3):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d-TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='d2a' 
       
        
    elif(TransferNr==4):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e-TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='e2a'
       
        
    elif(TransferNr==5):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f-TransferSum 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='f2a'
      
        
    elif(TransferNr==6):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2a'
       
        
    elif(TransferNr==7):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2a'
        
        
    elif(TransferNr==8):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2a'
       
        
    elif(TransferNr==9):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2a'
        
        
    elif(TransferNr==10):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2a'
        
        
    elif(TransferNr==11):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2a' 
        
    elif(TransferNr==12):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2a'  
        
    elif(TransferNr==13):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2a' 
       
    elif(TransferNr==14):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2a' 
        
    elif(TransferNr==15):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2a' 
        
    elif(TransferNr==16):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2a'
        
        
    elif(TransferNr==17):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2a'
        
        
    elif(TransferNr==18):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2a' 
       
        
    elif(TransferNr==19):
        value1tf=a+TransferSum
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2a' 
       
    ################################
    elif(TransferNr==20):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c-TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='c2b'  
        
    elif(TransferNr==21):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d-TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='d2b'  
       
    elif(TransferNr==22):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e-TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='e2b'
       
    elif(TransferNr==23):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f-TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='f2b'   
       
    elif(TransferNr==24):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2b'
       
    
    elif(TransferNr==25):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2b'
        
    elif(TransferNr==26):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2b'
        
    elif(TransferNr==27):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2b'
        
        
    elif(TransferNr==28):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2b'
       
        
    elif(TransferNr==29):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2b' 
       
    elif(TransferNr==30):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2b'   
       
    elif(TransferNr==31):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2b'
       
    elif(TransferNr==32):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2b'
       
    elif(TransferNr==33):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2b' 
       
    elif(TransferNr==34):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='rtb'  
       
    elif(TransferNr==35):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2b' 
        
    elif(TransferNr==36):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2b' 
       
    elif(TransferNr==37):
        value1tf=a
        value2tf=b+TransferSum
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2b' 
        
    #########################################
        
    elif(TransferNr==38):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d-TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='d2c'  
        
    elif(TransferNr==39):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e-TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='e2c'
       
    elif(TransferNr==40):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f-TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='f2c'  
        
    elif(TransferNr==41):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2c'
        
    elif(TransferNr==42):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2c'
       
    elif(TransferNr==43):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2c'
       
    elif(TransferNr==44):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2c'
       
    elif(TransferNr==45):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2c'
      
    elif(TransferNr==46):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2c' 
        
    elif(TransferNr==47):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2c'   
       
    elif(TransferNr==48):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2c'
       
    elif(TransferNr==49):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2c'
       
    elif(TransferNr==50):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2c'
      
    elif(TransferNr==51):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2c' 
       
    elif(TransferNr==52):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2c' 
      
    elif(TransferNr==53):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2u' 
       
        #################
    elif(TransferNr==54):
        value1tf=a
        value2tf=b
        value3tf=c+TransferSum
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2c'   
      
    ###################################### 
      
    elif(TransferNr==55):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e-TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='e2d'
        
        #########################
    elif(TransferNr==56):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f-TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='f2d'  
      
    elif(TransferNr==57):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2d'
       
    elif(TransferNr==58):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2d'
       
    elif(TransferNr==59):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2d'
       
        
    elif(TransferNr==60):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2d'
        
        
    elif(TransferNr==61):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2d'
        
    elif(TransferNr==62):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2d' 
        
    elif(TransferNr==63):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2d'
        
    elif(TransferNr==64):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2d' 
       
    elif(TransferNr==65):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2d'
        
    elif(TransferNr==66):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2d'  
        
    elif(TransferNr==67):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2d'  
      
    elif(TransferNr==68):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2d' 
      
    elif(TransferNr==69):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2d'  
        
    elif(TransferNr==70):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d+TransferSum
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2d' 
       
    ###########################
    
    elif(TransferNr==71):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f-TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='f2e'
        
    elif(TransferNr==72):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2e'
        
    elif(TransferNr==73):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2e'
       
    elif(TransferNr==74):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='j2e'
      
    elif(TransferNr==75):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2e'
       
    elif(TransferNr==76):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2e'
       
    elif(TransferNr==77):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2e' 
      
    elif(TransferNr==78):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2e'
        
    elif(TransferNr==79):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2e' 
        
    elif(TransferNr==80):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2e'
        
    elif(TransferNr==81):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2e' 
       
    elif(TransferNr==82):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2e'
        
    elif(TransferNr==83):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2e' 
        
    elif(TransferNr==84):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2e'  
       
    elif(TransferNr==85):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e+TransferSum
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2e' 
       
    ###########################
    
    elif(TransferNr==86):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g-TransferSum
        value8tf=h
        value9tf=j
        value10tf=k  
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='g2f'
      
    elif(TransferNr==87):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2f'
       
    elif(TransferNr==88):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2f'
       
    elif(TransferNr==89):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2f'
       
    elif(TransferNr==90):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2f'
        
    elif(TransferNr==91):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2f' 
      
    elif(TransferNr==92):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2f'  
        
    elif(TransferNr==93):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2f'   
        
    elif(TransferNr==94):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2f'
       
    elif(TransferNr==95):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2f'   
        
    elif(TransferNr==96):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2f'
       
    elif(TransferNr==97):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2f'
        
    elif(TransferNr==98):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t1f'
       
    elif(TransferNr==99):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f+TransferSum
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2f' 
       
    ########################
    
    elif(TransferNr==100):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f
        value7tf=g+TransferSum
        value8tf=h-TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2g'
        
    elif(TransferNr==101):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j-TransferSum
        value10tf=k 
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p 
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2g'
        
    elif(TransferNr==102):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2g'
        
    elif(TransferNr==103):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2g'
       
    elif(TransferNr==104):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2g' 
       
    elif(TransferNr==105):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2g'  
       
    elif(TransferNr==106):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2g' 
        
    elif(TransferNr==107):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2g'
        
    elif(TransferNr==108):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2g'
        
    elif(TransferNr==109):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2g' 
        
    elif(TransferNr==110):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2g'   
        
    elif(TransferNr==111):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2g'  
        
    elif(TransferNr==112):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g+TransferSum
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2g'  
        
    #####################
    
    elif(TransferNr==113):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j-TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='j2h'
        
    elif(TransferNr==114):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2h'
       
    elif(TransferNr==115):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2h'
       
    elif(TransferNr==116):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2h' 
       
    elif(TransferNr==117):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2h'   
       
    elif(TransferNr==118):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2h'   
      
    elif(TransferNr==119):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2h'
       
    elif(TransferNr==120):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2h'
       
    elif(TransferNr==121):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='h2r'  
       
    elif(TransferNr==122):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2h' 
     
    elif(TransferNr==123):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2h'
      
    elif(TransferNr==124):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h+TransferSum
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='h2u' 
       
    ############################
    elif(TransferNr==125):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k-TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='k2j'
      
    elif(TransferNr==126):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2j'
       
    elif(TransferNr==127):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2j' 
      
    elif(TransferNr==128):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='n2j'  
        
    elif(TransferNr==129):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2j'
       
    elif(TransferNr==130):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2j'
       
    elif(TransferNr==131):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='q2j'
        
    elif(TransferNr==132):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u 
        
        Quantile='r2j' 
        
    elif(TransferNr==133):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u 
        
        Quantile='s2j' 
       
    elif(TransferNr==134):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u 
        
        Quantile='t2j' 
       
    elif(TransferNr==135):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j+TransferSum
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2j'    
       
    #######################################
    elif(TransferNr==136):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l-TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2k'
       
        
    elif(TransferNr==137):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2k' 
       
        
    elif(TransferNr==138):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2k' 
      
    elif(TransferNr==139):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2k'
      
    elif(TransferNr==140):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2k'
       
    elif(TransferNr==141):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2k' 
      
    elif(TransferNr==142):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2k' 
       
    elif(TransferNr==143):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2k' 
       
    elif(TransferNr==144):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2k'  
      
    elif(TransferNr==145):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k+TransferSum
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2k' 
      
    ##################################
    elif(TransferNr==146):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m-TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='m2l' 
     
    elif(TransferNr==147):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='l2n'    
        
    elif(TransferNr==148):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2l'
        
    elif(TransferNr==149):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2l'
       
    elif(TransferNr==150):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2l'
       
    elif(TransferNr==151):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2l'
        
    elif(TransferNr==152):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2l' 
       
    elif(TransferNr==153):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2l' 
       
    elif(TransferNr==154):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l+TransferSum
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2l' 
       
    ########################
    elif(TransferNr==155):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n-TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='n2m'    
        
    elif(TransferNr==156):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2m'  
        
    elif(TransferNr==157):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2m'
        
    elif(TransferNr==158):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2m'
      
    elif(TransferNr==159):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2m'  
       
    elif(TransferNr==160):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2m'
        
    elif(TransferNr==161):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2m'
        
    elif(TransferNr==162):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m+TransferSum
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2m'             
       
    #########################################
    elif(TransferNr==163):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o-TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='o2n' 
        
    elif(TransferNr==164):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2n'
        
    elif(TransferNr==165):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2n'  
     
    elif(TransferNr==166):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2n'   
       
    elif(TransferNr==167):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2n'     
        
    elif(TransferNr==168):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2n' 
       
    elif(TransferNr==169):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n+TransferSum
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2n' 
      
    ##############################
    elif(TransferNr==170):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p-TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='p2o'
       
    elif(TransferNr==171):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2o'
       
    elif(TransferNr==172):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2o' 
       
    elif(TransferNr==173):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2o' 
       
    elif(TransferNr==174):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2o' 
        
    elif(TransferNr==175):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o+TransferSum
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2o' 
        
    ##################################
    elif(TransferNr==176):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p+TransferSum
        value16tf=q-TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='q2p' 
      
    elif(TransferNr==177):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p+TransferSum
        value16tf=q
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2p' 
        
    elif(TransferNr==178):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p+TransferSum
        value16tf=q
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2p'  
       
    elif(TransferNr==179):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p+TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2p'  
        
    elif(TransferNr==180):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p+TransferSum
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2p'
       
    ##############################   
    elif(TransferNr==181):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q+TransferSum
        value17tf=r-TransferSum
        value18tf=s
        value19tf=t
        value20tf=u
        
        Quantile='r2q'
       
    elif(TransferNr==182):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q+TransferSum
        value17tf=r
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2q'  
      
    elif(TransferNr==183):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q+TransferSum
        value17tf=r
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2q'  
       
    elif(TransferNr==184):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q+TransferSum
        value17tf=r
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2q' 
       
    #############################
    elif(TransferNr==185):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r+TransferSum
        value18tf=s-TransferSum
        value19tf=t
        value20tf=u
        
        Quantile='s2r' 
        
    elif(TransferNr==186):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r+TransferSum
        value18tf=s
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2r' 
       
    elif(TransferNr==187):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r+TransferSum
        value18tf=s
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2r'
        
    ##############################
    elif(TransferNr==188):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s+TransferSum
        value19tf=t-TransferSum
        value20tf=u
        
        Quantile='t2s'
        
    elif(TransferNr==189):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s+TransferSum
        value19tf=t
        value20tf=u-TransferSum
        
        Quantile='u2s'
       
    ###############################
    elif(TransferNr==190):
        value1tf=a
        value2tf=b
        value3tf=c
        value4tf=d
        value5tf=e
        value6tf=f 
        value7tf=g
        value8tf=h
        value9tf=j
        value10tf=k
        value11tf=l
        value12tf=m
        value13tf=n
        value14tf=o
        value15tf=p
        value16tf=q
        value17tf=r
        value18tf=s
        value19tf=t+TransferSum
        value20tf=u-TransferSum
        
        Quantile='u2t'
        
          
    #######################################################
    
    wlisttf =[value1tf,value2tf,value3tf,value4tf,value5tf,value6tf,value7tf,value8tf,value9tf,value10tf,
              value11tf,value12tf,value13tf,value14tf,value15tf,value16tf,value17tf,value18tf,value19tf,value20tf]
    wlisttf.sort()
    
    atf=wlisttf[0]
    btf=wlisttf[1]
    ctf=wlisttf[2]
    dtf=wlisttf[3]
    etf=wlisttf[4]
    ftf=wlisttf[5]
    gtf=wlisttf[6]
    htf=wlisttf[7]
    jtf=wlisttf[8]
    ktf=wlisttf[9]
    
    ltf=wlisttf[10]
    mtf=wlisttf[11]
    ntf=wlisttf[12]
    otf=wlisttf[13]
    ptf=wlisttf[14]
    qtf=wlisttf[15]
    rtf=wlisttf[16]
    stf=wlisttf[17]
    ttf=wlisttf[18]
    utf=wlisttf[19]
    
    ###################################################################################################
    
    
    g1 = (a/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g2 = (b/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g3 = (c/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g4 = (d/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g5 = (e/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g6 = (f/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g7 = (g/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g8 = (h/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g9 = (j/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g10 = (k/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g11 = (l/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g12 = (m/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g13 = (n/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g14 = (o/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g15 = (p/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g16 = (q/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g17 = (r/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g18 = (s/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g19 = (t/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g20 = (u/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))       
   
   
   
   
    g1tf = (atf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g2tf = (btf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g3tf = (ctf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g4tf = (dtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g5tf = (etf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g6tf = (ftf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g7tf = (gtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g8tf = (htf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g9tf = (jtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g10tf = (ktf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g11tf = (ltf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g12tf = (mtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g13tf = (ntf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g14tf = (otf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g15tf = (ptf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g16tf = (qtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g17tf = (rtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g18tf = (stf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g19tf = (ttf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g20tf = (utf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))       

  
    ##############################################################################################
    #Income shares
    percent1=round(g1*100,99)
    percent2=round(g2*100,99)
    percent3=round(g3*100,99)
    percent4=round(g4*100,99)
    percent5=round(g5*100,99)
    percent6=round(g6*100,99)
    percent7=round(g7*100,99)
    percent8=round(g8*100,99)
    percent9=round(g9*100,99)
    percent10=round(g10*100,99)
    percent11=round(g11*100,99)
    percent12=round(g12*100,99)
    percent13=round(g13*100,99)
    percent14=round(g14*100,99)
    percent15=round(g15*100,99)
    percent16=round(g16*100,99)
    percent17=round(g17*100,99)
    percent18=round(g18*100,99)
    percent19=round(g19*100,99)
    percent20=round(g20*100,99)         
    
    percent1tf=round(g1tf*100,99)
    percent2tf=round(g2tf*100,99)
    percent3tf=round(g3tf*100,99)
    percent4tf=round(g4tf*100,99)
    percent5tf=round(g5tf*100,99)
    percent6tf=round(g6tf*100,99)
    percent7tf=round(g7tf*100,99)
    percent8tf=round(g8tf*100,99)
    percent9tf=round(g9tf*100,99)
    percent10tf=round(g10tf*100,99)
             
    percent11tf=round(g11tf*100,99)
    percent12tf=round(g12tf*100,99)
    percent13tf=round(g13tf*100,99)
    percent14tf=round(g14tf*100,99)
    percent15tf=round(g15tf*100,99)
    percent16tf=round(g16tf*100,99)
    percent17tf=round(g17tf*100,99)
    percent18tf=round(g18tf*100,99)
    percent19tf=round(g19tf*100,99)
    percent20tf=round(g20tf*100,99)        
    
    #Cummulative income shares
    q1cmltv=percent1
    q2cmltv=q1cmltv+percent2
    q3cmltv=q2cmltv+percent3
    q4cmltv=q3cmltv+percent4
    q5cmltv=q4cmltv+percent5
    q6cmltv=q5cmltv+percent6
    q7cmltv=q6cmltv+percent7
    q8cmltv=q7cmltv+percent8
    q9cmltv=q8cmltv+percent9
    q10cmltv=q9cmltv+percent10
    q11cmltv=q10cmltv+percent11
    q12cmltv=q11cmltv+percent12
    q13cmltv=q12cmltv+percent13
    q14cmltv=q13cmltv+percent14
    q15cmltv=q14cmltv+percent15
    q16cmltv=q15cmltv+percent16
    q17cmltv=q16cmltv+percent17
    q18cmltv=q17cmltv+percent18
    q19cmltv=q18cmltv+percent19
    q20cmltv=q19cmltv+percent20         
    
    q1cmltvtf=percent1tf
    q2cmltvtf=q1cmltvtf+percent2tf
    q3cmltvtf=q2cmltvtf+percent3tf
    q4cmltvtf=q3cmltvtf+percent4tf
    q5cmltvtf=q4cmltvtf+percent5tf
    q6cmltvtf=q5cmltvtf+percent6tf
    q7cmltvtf=q6cmltvtf+percent7tf
    q8cmltvtf=q7cmltvtf+percent8tf
    q9cmltvtf=q8cmltvtf+percent9tf
    q10cmltvtf=q9cmltvtf+percent10tf
    q11cmltvtf=q10cmltvtf+percent11tf
    q12cmltvtf=q11cmltvtf+percent12tf
    q13cmltvtf=q12cmltvtf+percent13tf
    q14cmltvtf=q13cmltvtf+percent14tf
    q15cmltvtf=q14cmltvtf+percent15tf
    q16cmltvtf=q15cmltvtf+percent16tf
    q17cmltvtf=q16cmltvtf+percent17tf
    q18cmltvtf=q17cmltvtf+percent18tf
    q19cmltvtf=q18cmltvtf+percent19tf
    q20cmltvtf=q19cmltvtf+percent20tf         
   
    
    #################################################################################################
    ################################################################################################
    ###############################################################################################
    #Gini coefficient from distances
    
    quantile1=5
    quantile2=10
    quantile3=15
    quantile4=20
    quantile5=25
    quantile6=30
    quantile7=35
    quantile8=40
    quantile9=45
    quantile10=50
    quantile11=55        
    quantile12=60
    quantile13=65
    quantile14=70
    quantile15=75
    quantile16=80
    quantile17=85
    quantile18=90
    quantile19=95
             
    sumquantiles=950
    
    #n-1 distances between Lorenz curve and 45-degree line
    distance1=abs((quantile1)-(q1cmltv))
    distance2=abs((quantile2)-(q2cmltv))
    distance3=abs((quantile3)-(q3cmltv))
    distance4=abs((quantile4)-(q4cmltv))
    distance5=abs((quantile5)-(q5cmltv))
    distance6=abs((quantile6)-(q6cmltv))
    distance7=abs((quantile7)-(q7cmltv))
    distance8=abs((quantile8)-(q8cmltv))
    distance9=abs((quantile9)-(q9cmltv))
    distance10=abs((quantile10)-(q10cmltv))
             
    distance11=abs((quantile11)-(q11cmltv))
    distance12=abs((quantile12)-(q12cmltv))
    distance13=abs((quantile13)-(q13cmltv))
    distance14=abs((quantile14)-(q14cmltv))
    distance15=abs((quantile15)-(q15cmltv))
    distance16=abs((quantile16)-(q16cmltv))
    distance17=abs((quantile17)-(q17cmltv))
    distance18=abs((quantile18)-(q18cmltv))
    distance19=abs((quantile19)-(q19cmltv))         
   
    
    sumdistances=(distance1+distance2+distance3+distance4+distance5+
                  distance6+distance7+distance8+distance9+distance10+
                  distance11+distance12+distance13+distance14+distance15+
                  distance16+distance17+distance18+distance19 )
    
    preGini=sumdistances/sumquantiles
    
    Gini=preGini*(19/20)
    
    ###############################################################################################
    #Gini coefficient after a progressive (income) transfer
    
    distance1tf=abs((quantile1)-(q1cmltvtf))
    distance2tf=abs((quantile2)-(q2cmltvtf))
    distance3tf=abs((quantile3)-(q3cmltvtf))
    distance4tf=abs((quantile4)-(q4cmltvtf))
    distance5tf=abs((quantile5)-(q5cmltvtf))
    distance6tf=abs((quantile6)-(q6cmltvtf))
    distance7tf=abs((quantile7)-(q7cmltvtf))
    distance8tf=abs((quantile8)-(q8cmltvtf))
    distance9tf=abs((quantile9)-(q9cmltvtf))
    distance10tf=abs((quantile10)-(q10cmltvtf))         
             
    distance11tf=abs((quantile11)-(q11cmltvtf))
    distance12tf=abs((quantile12)-(q12cmltvtf))
    distance13tf=abs((quantile13)-(q13cmltvtf))
    distance14tf=abs((quantile14)-(q14cmltvtf))
    distance15tf=abs((quantile15)-(q15cmltvtf))
    distance16tf=abs((quantile16)-(q16cmltvtf))
    distance17tf=abs((quantile17)-(q17cmltvtf))
    distance18tf=abs((quantile18)-(q18cmltvtf))
    distance19tf=abs((quantile19)-(q19cmltvtf))
    
    sumdistancestf=(distance1tf+distance2tf+distance3tf+distance4tf+distance5tf+
                    distance6tf+distance7tf+distance8tf+distance9tf+distance10tf+
                    distance11tf+distance12tf+distance13tf+distance14tf+distance15tf+
                    distance16tf+distance17tf+distance18tf+distance19tf)
    
    preGinitf=sumdistancestf/sumquantiles
    
    Ginitf=preGinitf*(19/20)
    Ginid=100-((100/Gini)*Ginitf)
    
    ################################################################################################
    ###############################################################################################
    #rGini sensitive to right skewness
    
    #Attaching weights to distances that increase with the rank in the cummulative distribution
    rdistance1=distance1*rweight1
    rdistance2=distance2*rweight2
    rdistance3=distance3*rweight3
    rdistance4=distance4*rweight4
    rdistance5=distance5*rweight5
    rdistance6=distance6*rweight6
    rdistance7=distance7*rweight7
    rdistance8=distance8*rweight8
    rdistance9=distance9*rweight9
    rdistance10=distance10*rweight10
    
    rdistance11=distance11*rweight11
    rdistance12=distance12*rweight12
    rdistance13=distance13*rweight13
    rdistance14=distance14*rweight14
    rdistance15=distance15*rweight15
    rdistance16=distance16*rweight16
    rdistance17=distance17*rweight17
    rdistance18=distance18*rweight18
    rdistance19=distance19*rweight19
   
    
    sumrdistances=(rdistance1+rdistance2+rdistance3+rdistance4+rdistance5+
                   rdistance6+rdistance7+rdistance8+rdistance9+rdistance10+
                   rdistance11+rdistance12+rdistance13+rdistance14+rdistance15+
                   rdistance16+rdistance17+rdistance18+rdistance19)
    
    prerGini=sumrdistances/sumquantiles
    
    rGini=prerGini*(19/20)
    
    ###############################################################################################
    #rGini after progressive (income) transfer
    
    rdistance1tf=distance1tf*rweight1
    rdistance2tf=distance2tf*rweight2
    rdistance3tf=distance3tf*rweight3
    rdistance4tf=distance4tf*rweight4
    rdistance5tf=distance5tf*rweight5
    rdistance6tf=distance6tf*rweight6
    rdistance7tf=distance7tf*rweight7
    rdistance8tf=distance8tf*rweight8
    rdistance9tf=distance9tf*rweight9
    rdistance10tf=distance10tf*rweight10
    
    rdistance11tf=distance11tf*rweight11
    rdistance12tf=distance12tf*rweight12
    rdistance13tf=distance13tf*rweight13
    rdistance14tf=distance14tf*rweight14
    rdistance15tf=distance15tf*rweight15
    rdistance16tf=distance16tf*rweight16
    rdistance17tf=distance17tf*rweight17
    rdistance18tf=distance18tf*rweight18
    rdistance19tf=distance19tf*rweight19
    
    sumrdistancestf=(rdistance1tf+rdistance2tf+rdistance3tf+rdistance4tf+rdistance5tf+
                     rdistance6tf+rdistance7tf+rdistance8tf+rdistance9tf+rdistance10tf+
                     rdistance11tf+rdistance12tf+rdistance13tf+rdistance14tf+rdistance15tf+
                     rdistance16tf+rdistance17tf+rdistance18tf+rdistance19tf)
    
    prerGinitf=sumrdistancestf/sumquantiles
    
    rGinitf=prerGinitf*(19/20)
    
    #Difference between values of rGini before and after a progressive transfer occured in the distribution
    rGinid=100-((100/rGini)*rGinitf)
    
    ################################################################################################
    ###############################################################################################
    #lGini(=Gini_skminus, sensitive to negative/left skewness)
    
    #Attaching weights to distances that decrease with the rank in the cummulative distribution
    ldistance1=distance1*lweight1
    ldistance2=distance2*lweight2
    ldistance3=distance3*lweight3
    ldistance4=distance4*lweight4
    ldistance5=distance5*lweight5
    ldistance6=distance6*lweight6
    ldistance7=distance7*lweight7
    ldistance8=distance8*lweight8
    ldistance9=distance9*lweight9
    ldistance10=distance10*lweight10
    
    ldistance11=distance11*lweight11
    ldistance12=distance12*lweight12
    ldistance13=distance13*lweight13
    ldistance14=distance14*lweight14
    ldistance15=distance15*lweight15
    ldistance16=distance16*lweight16
    ldistance17=distance17*lweight17
    ldistance18=distance18*lweight18
    ldistance19=distance19*lweight19
    
    sumldistances=(ldistance1+ldistance2+ldistance3+ldistance4+ldistance5+
                   ldistance6+ldistance7+ldistance8+ldistance9+ldistance10+
                   ldistance11+ldistance12+ldistance13+ldistance14+ldistance15+
                   ldistance16+ldistance17+ldistance18+ldistance19)
    
    prelGini=sumldistances/sumquantiles
    
    lGini=prelGini*(19/20)
    
    ###############################################################################################
    #lGini (=Gini_sk-) after a progressive (income) transfer
    
    ldistance1tf=distance1tf*lweight1
    ldistance2tf=distance2tf*lweight2
    ldistance3tf=distance3tf*lweight3
    ldistance4tf=distance4tf*lweight4
    ldistance5tf=distance5tf*lweight5
    ldistance6tf=distance6tf*lweight6
    ldistance7tf=distance7tf*lweight7
    ldistance8tf=distance8tf*lweight8
    ldistance9tf=distance9tf*lweight9
    ldistance10tf=distance10tf*lweight10
    
    ldistance11tf=distance11tf*lweight11
    ldistance12tf=distance12tf*lweight12
    ldistance13tf=distance13tf*lweight13
    ldistance14tf=distance14tf*lweight14
    ldistance15tf=distance15tf*lweight15
    ldistance16tf=distance16tf*lweight16
    ldistance17tf=distance17tf*lweight17
    ldistance18tf=distance18tf*lweight18
    ldistance19tf=distance19tf*lweight19
   
    
    sumldistancestf=(ldistance1tf+ldistance2tf+ldistance3tf+ldistance4tf+ldistance5tf+
                     ldistance6tf+ldistance7tf+ldistance8tf+ldistance9tf+ldistance10tf+
                     ldistance11tf+ldistance12tf+ldistance13tf+ldistance14tf+ldistance15tf+
                     ldistance16tf+ldistance17tf+ldistance18tf+ldistance19tf)
    
    prelGinitf=sumldistancestf/sumquantiles
    
    lGinitf=prelGinitf*(19/20)
    
    #Difference between values of lGini before and after a progressive transfer occured in the distribution
    lGinid=100-((100/lGini)*lGinitf)
    ##########################################################
    #A skweness adjusted Gini coefficient
    Gsk=Gini+(abs(rGini-lGini)/2)
    Gsktf=Ginitf+(abs(rGinitf-lGinitf)/2)
    Gskd=100-((100/Gsk)*Gsktf)
    
    ######################################################################
    #Index S 
    
    absdifferential1=abs(rdistance1-ldistance1)
    absdifferential2=abs(rdistance2-ldistance2)
    absdifferential3=abs(rdistance3-ldistance3)
    absdifferential4=abs(rdistance4-ldistance4)  
    absdifferential5=abs(rdistance5-ldistance5)
    absdifferential6=abs(rdistance6-ldistance6)
    absdifferential7=abs(rdistance7-ldistance7)
    absdifferential8=abs(rdistance8-ldistance8) 
    absdifferential9=abs(rdistance9-ldistance9) 
    absdifferential10=abs(rdistance10-ldistance10) 
    
    absdifferential11=abs(rdistance11-ldistance11)
    absdifferential12=abs(rdistance12-ldistance12)
    absdifferential13=abs(rdistance13-ldistance13)
    absdifferential14=abs(rdistance14-ldistance14)  
    absdifferential15=abs(rdistance15-ldistance15)
    absdifferential16=abs(rdistance16-ldistance16)
    absdifferential17=abs(rdistance17-ldistance17)
    absdifferential18=abs(rdistance18-ldistance18) 
    absdifferential19=abs(rdistance19-ldistance19)  
    
    sumabsdiffernetials=(
                         absdifferential17+absdifferential18+absdifferential19)
    
    preIndexS=sumabsdiffernetials/sumquantiles
    IndexS=preIndexS*19/20
    
    ################################################################################
    # Index W
    
    IndexW=Gini+(IndexS/2)
    
    ######################################################################
    #Index S after progressive (income) transfer
    
    absdifferential1tf=abs(rdistance1tf-ldistance1tf)
    absdifferential2tf=abs(rdistance2tf-ldistance2tf)
    absdifferential3tf=abs(rdistance3tf-ldistance3tf)
    absdifferential4tf=abs(rdistance4tf-ldistance4tf)  
    absdifferential5tf=abs(rdistance5tf-ldistance5tf)
    absdifferential6tf=abs(rdistance6tf-ldistance6tf)
    absdifferential7tf=abs(rdistance7tf-ldistance7tf)
    absdifferential8tf=abs(rdistance8tf-ldistance8tf) 
    absdifferential9tf=abs(rdistance9tf-ldistance9tf) 
    absdifferential10tf=abs(rdistance10tf-ldistance10tf) 
    
    absdifferential11tf=abs(rdistance11tf-ldistance11tf)
    absdifferential12tf=abs(rdistance12tf-ldistance12tf)
    absdifferential13tf=abs(rdistance13tf-ldistance13tf)
    absdifferential14tf=abs(rdistance14tf-ldistance14tf)  
    absdifferential15tf=abs(rdistance15tf-ldistance15tf)
    absdifferential16tf=abs(rdistance16tf-ldistance16tf)
    absdifferential17tf=abs(rdistance17tf-ldistance17tf)
    absdifferential18tf=abs(rdistance18tf-ldistance18tf) 
    absdifferential19tf=abs(rdistance19tf-ldistance19tf) 
    
    sumabsdiffernetialstf=(
                           absdifferential17tf+absdifferential18tf+absdifferential19tf)
    
    preIndexStf=sumabsdiffernetialstf/sumquantiles
    IndexStf=preIndexStf*19/20
    
    #############################################################
    #Differences between values of Index S before and after a progressive(income) transfer occured in the distribution
    IndexSd=100-((100/IndexS)*IndexStf)
    ###############################################
    # Index W after a progressive (income) transfer
    IndexWtf=Ginitf+(IndexStf/2)
    #Differences between values of Index W before and after a progressive(income) transfer occured in the distribution
    IndexWd=100-((100/IndexW)*IndexWtf)
    
    ##################################################################################################
    #################################################################################################
    ################################################################################################
    #Skewness Measures
    ################################################################################################
    #Conventional skewness measures
    
    #Skewness based on mean, median and standard deviation
    skewness_paerson1=(3 * (mean - median)) / stdv
    
    #Skew: Standard method to calculate skewness based on higher moments
    
    skew1=pow((a-mean),3)
    skew2=pow((b-mean),3)
    skew3=pow((c-mean),3)
    skew4=pow((d-mean),3)
    skew5=pow((e-mean),3)
    skew6=pow((f-mean),3)
    skew7=pow((g-mean),3)
    skew8=pow((h-mean),3)
    skew9=pow((j-mean),3)
    skew10=pow((k-mean),3)
    
    skew11=pow((l-mean),3)
    skew12=pow((m-mean),3)
    skew13=pow((n-mean),3)
    skew14=pow((o-mean),3)
    skew15=pow((p-mean),3)
    skew16=pow((q-mean),3)
    skew17=pow((r-mean),3)
    skew18=pow((s-mean),3)
    skew19=pow((t-mean),3)
    skew20=pow((u-mean),3)
   
    skewsum=(skew1+skew2+skew3+skew4+skew5+
             skew6+skew7+skew8+skew9+skew10+
             skew11+skew12+skew13+skew14+skew15+
             skew16+skew17+skew18+skew19+skew20)
    
    Skew=skewsum/ (20 * pow(stdv,3))
    #Skew_=scipy.stats.skew(wlist, axis=0, bias=True)
    
    #Another version of a standard moment-based measure of skewness
    Skew2=((20/((20-1)*(20-2)))*(skewsum/pow(stdv,3)))
    
    ######################################################## 
    #Novel skewness measures
    
    #d-metric = (n/n-1)[1.5(rGini-lGini)]
    #Gsk equals G plus a third of the percentage expressed in the d-metric, for n large enough
    dMetric=(20/19)*(1.5*(rGini-lGini))
    absdMetric=abs((20/19)*(1.5*(rGini-lGini)))
    dMetricDollar=absdMetric*summ
    
    #measure b 
    bMeasureComp1=(1-((1/rGini)*lGini))
    bMeasureComp2=(((1/lGini)*rGini)-1)
    
    bMeasure=(bMeasureComp1+bMeasureComp2)/1.5

    #################################
    # Does the novel measure b indicate a different skewness than the standard moment-based measure of skewness?
    if((bMeasure<0) and (Skew>0)):
        skewdivergence="yes"
    elif((bMeasure>0) and (Skew<0)):   
         skewdivergence="yes"
    elif((bMeasure<=0) and (Skew<=0)):
         skewdivergence="no"
    elif((bMeasure>=0) and (Skew>=0)):
         skewdivergence="no"
             
    #################################
    #Testing how the novel skewness measure b and the standard measure conform to the rule of thumb...
    #...that the mean is right of the median under right skew, and left of the median under left skew
    
    if((mean>median) and (bMeasure>=0)):
        bMMconform="yes"
    elif((mean<median) and (bMeasure<=0)):
        bMMconform="yes" 
    elif((mean<median) and (bMeasure>=0)):   
        bMMconform="no"
    elif((mean>median) and (bMeasure<0)):
        bMMconform="no"    
    #################################
    
    if((mean>median) and (Skew>=0)):
        SkewMMconform="yes"
    elif((mean<median) and (Skew<=0)):
        SkewMMconform="yes" 
    elif((mean<median) and (Skew>=0)):   
        SkewMMconform="no"
    elif((mean>median) and (Skew<0)):
        SkewMMconform="no"        
    
    ################################################################################################
    ###############################################################################################
    ##############################################################################################
    
    value1=a
    value2=b
    value3=c
    value4=d
    value5=e
    value6=f
    value7=g
    value8=h
    value9=j
    value10=k
    value11=l
    value12=m
    value13=n
    value14=o
    value15=p
    value16=q
    value17=r
    value18=s
    value19=t
    value20=u 
    
    value1tf=atf
    value2tf=btf
    value3tf=ctf
    value4tf=dtf
    value5tf=etf
    value6tf=ftf
    value7tf=gtf
    value8tf=htf
    value9tf=jtf
    value10tf=ktf
    value11tf=ltf
    value12tf=mtf
    value13tf=ntf
    value14tf=otf
    value15tf=ptf
    value16tf=qtf
    value17tf=rtf
    value18tf=stf
    value19tf=ttf
    value20tf=utf 
   
    #################################################################################
    i+=1
      
    dataframe2.loc[len(dataframe2)] = (TransferNr,Quantile,TransferSum,
                                       Gini,Ginitf,Ginid,CV,
                                       rGini,rGinitf,rGinid,
                                       lGini,lGinitf,lGinid,
                                       Gsk,Gsktf,Gskd,
                                       IndexS,IndexStf,IndexSd,
                                       IndexW,IndexWtf,IndexWd,
                                       skewness_paerson1,Skew,Skew2,
                                       dMetric,absdMetric,summ,dMetricDollar,bMeasure,
                                       skewdivergence,SkewMMconform,bMMconform,
                                       mean,median,stdv,
                                       percent1,percent2,percent3,percent4,percent5,
                                       percent6,percent7,percent8,percent9,percent10,
                                       percent11,percent12,percent13,percent14,percent15,
                                       percent16,percent17,percent18,percent19,percent20,
                                       percent1tf,percent2tf,percent3tf,percent4tf,percent5tf,
                                       percent6tf,percent7tf,percent8tf,percent9tf,percent10tf,
                                       percent11tf,percent12tf,percent13tf,percent14tf,percent15tf,
                                       percent16tf,percent17tf,percent18tf,percent19tf,percent20tf,
                                       value1,value2,value3,value4,value5,
                                       value6,value7,value8,value9,value10,
                                       value11,value12,value13,value14,value15,
                                       value16,value17,value18,value19,value20,
                                       value1tf,value2tf,value3tf,value4tf,value5tf,
                                       value6tf,value7tf,value8tf,value9tf,value10tf,
                                       value11tf,value12tf,value13tf,value14tf,value15tf,
                                       value16tf,value17tf,value18tf,value19tf,value20tf           
                                      )

# %%
dataframe2
# Out:
#      TransferNr Quantile  TransferSum      Gini    Ginitf     Ginid        CV  \
# 0            94      p2f         0.20  0.486576  0.486528  0.009805  0.982582
# 1            31      o2b         0.10  0.356483  0.356446  0.010393  0.663498
# 2           170      p2o         0.10  0.457397  0.457394  0.000666  0.962969
# 3            77      m2e         0.30  0.533145  0.533095  0.009457  1.130782
# 4            39      e2c         0.10  0.512753  0.512750  0.000598  1.022113
# ...         ...      ...          ...       ...       ...       ...       ...
# 4996        163      o2n         0.49  0.429822  0.429807  0.003491  0.836917
# 4997        107      p2g         0.30  0.554334  0.554280  0.009773  1.117707
# 4998        173      s2o         0.49  0.468077  0.468014  0.013421  0.874933
# 4999        161      t2m         0.20  0.492298  0.492261  0.007618  1.107870
# 5000         22      e2b         0.20  0.497371  0.497356  0.003079  0.949117
#
# ...

# %%
dataframe2.to_excel(r'C:/Documents/.../Measures_n20_TransferSensitivity.xlsx', sheet_name='Sheet1', index = True)
